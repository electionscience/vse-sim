# %%
from cid import *

# %%
plur = CID(KSModel(), [Plurality], 96, 6, 20000, numBuckets=48)
plur.saveFile("plurOnly", False)
plur.chart()

# %%
basesw = CID(KSModel(), [Plurality, PluralityTop2, IRV, (Approval, Approval.zeroInfoBallot), (ApprovalTop2, ApprovalTop2.zeroInfoBallot), STAR, Minimax],
             72, 6, 10000)
basesw.saveFile("basesw", False)
basesw.chart()

# %%
basemw = CID(KSModel(), [SNTV, STV, AllocatedScore, SequentialMonroe], 72, 10, 5000, 4)
basemw.saveFile("basemw", False)
basemw.chart()

# %%
basemw.saveFile("basemw", False)

# %%
mwpickycid = CID(KSModel(),[STV, (SPAV, Approval.zeroInfoBallot, {'pickiness':0.6}),
                            (AllocatedScore, STAR.zeroInfoBallot, {'exponent':4}), (AllocatedScore, STAR.zeroInfoBallot, {'exponent':10}),
                            (SSS, STAR.zeroInfoBallot, {'exponent':4}), (SSS, STAR.zeroInfoBallot, {'exponent':10}),
                            (SequentialMonroe, STAR.zeroInfoBallot, {'exponent':4}), (SequentialMonroe, STAR.zeroInfoBallot, {'exponent':10}),
                            (ASRDroop, STAR.zeroInfoBallot, {'exponent':4}), (ASRDroop, STAR.zeroInfoBallot, {'exponent':4})],
                 72, 10, 1000, 4)
mwpickycid.saveFile("mwpicky")
mwpickycid.chart(False)

# %%
mwnaive = CID(KSModel(),[STV, SNTV, (SPAV, Approval.zeroInfoBallot, {'pickiness':0.6}),
                         AllocatedScore, SSS, SequentialMonroe, ASRDroop],
                 72, 10, 1000, 4)
mwnaive.saveFile("mwNaive", False)
mwnaive.chart()

# %%
smallDevs = CID(KSModel(), [Plurality, PluralityTop2, IRV, (Approval, Approval.zeroInfoBallot), (ApprovalTop2, ApprovalTop2.zeroInfoBallot), STAR, Minimax],
             72, 6, 10000, utilChange = 0.02)
smallDevs.saveFile("smallDevSW", False)
smallDevs.chart()

# %%
sw3 = CID(KSModel(), [Plurality, PluralityTop2, IRV, (Approval, Approval.zeroInfoBallot), (ApprovalTop2, ApprovalTop2.zeroInfoBallot), STAR, Minimax],
          72, 3, 10000)
sw3.saveFile("sw3", False)
sw3.chart()

# %%
sw12 = CID(KSModel(), [Plurality, PluralityTop2, IRV, (Approval, Approval.zeroInfoBallot), (ApprovalTop2, ApprovalTop2.zeroInfoBallot), STAR, Minimax],
           72, 12, 3000)
sw12.saveFile("sw12", False)
sw12.chart()

# %%
mw20 = CID(KSModel(), [SNTV, STV, AllocatedScore, SequentialMonroe], 72, 20, 2000, 4)
mw20.saveFile("mw20", False)
mw20.chart()

# %%
mw2winners = CID(KSModel(), [SNTV, STV, AllocatedScore, SequentialMonroe], 72, 10, 5000, 2)
mw2winners.saveFile("mw2w", False)
mw2winners.chart()

# %%
mwutils = CID(KSModel(), [STV, AllocatedScore, SequentialMonroe], 72, 10, 500, 4, sorter=utilDeviation)
mwutils.chart()

# %%
swAffinity = CID(KSModel(), [Plurality, PluralityTop2, IRV, (Approval, Approval.zeroInfoBallot), (ApprovalTop2, ApprovalTop2.zeroInfoBallot), STAR, Minimax], 
             72, 6, 2000, sorter=candAffinity)
swAffinity.saveFile("candAffinity", False)
swAffinity.chart()

# %%
swNormalized = CID(KSModel(), [Plurality, PluralityTop2, IRV, (Approval, Approval.zeroInfoBallot), (ApprovalTop2, ApprovalTop2.zeroInfoBallot), STAR, Minimax], 
             72, 6, 2000, sorter=normalizedUtilDeviation)
swNormalized.saveFile("normUtils", False)
swNormalized.chart()

# %%
swUnnormalized = CID(KSModel(), [Plurality, PluralityTop2, IRV, (Approval, Approval.zeroInfoBallot), (ApprovalTop2, ApprovalTop2.zeroInfoBallot), STAR, Minimax], 
             72, 6, 2000, sorter=utilDeviation)
swUnnormalized.saveFile("unnormedUtils", False)
swUnnormalized.chart()

# %%
swWeighted = CID(KSModel(), [Plurality, PluralityTop2, IRV, (Approval, Approval.zeroInfoBallot), (ApprovalTop2, ApprovalTop2.zeroInfoBallot), STAR, Minimax], 
             72, 6, 2000, sorter=weightedUtilDev)
swWeighted.saveFile("weightedUtils", False)
swWeighted.chart()

# %%
swva = CID(KSModel(), [(Plurality, Plurality.vaBallot), (PluralityTop2, PluralityTop2.vaBallot),
                                  (IRV, IRV.vaBallot), (Approval, Approval.vaBallot),
                                  (ApprovalTop2, ApprovalTop2.vaBallot),
                                  (STAR, STAR.vaBallot), Minimax], 72, 6, 5000)
swva.saveFile("swva6new", False)
swva.chart()

# %%
swva2 = CID(KSModel(), [(Plurality, Plurality.vaBallot), (PluralityTop2, PluralityTop2.vaBallot),
                                  (IRV, IRV.vaBallot), (Approval, Approval.vaBallot),
                                  (ApprovalTop2, ApprovalTop2.vaBallot),
                                  (STAR, STAR.vaBallot), Minimax], 72, 6, 500)
#swva.saveFile("swva6new", False)
swva2.chart()

# %%
swvapap = CID(KSModel(), [(Plurality, Plurality.vaBallot), (PluralityTop2, PluralityTop2.vaBallot),
                                  (IRV, IRV.vaBallot), (Approval, Approval.vaBallot),
                                  (ApprovalTop2, ApprovalTop2.vaBallot),
                                  (STAR, STAR.vaBallot), Minimax], 24, 6, 500, numBuckets=12, pollAfterPert=True)
swvapap.saveFile("swvapap", False)
swvapap.chart()

# %%
swvapap2 = CID(KSModel(), [(Plurality, Plurality.vaBallot), (PluralityTop2, PluralityTop2.vaBallot),
                                  (IRV, IRV.vaBallot), (Approval, Approval.vaBallot),
                                  (ApprovalTop2, ApprovalTop2.vaBallot)], 24, 6, 500, numBuckets=12, pollAfterPert=True)
#swvapap2.saveFile("swvapap", False)
swvapap2.chart(False)

# %%
swva.chart()

# %%
swva12 = CID(KSModel(), [(Plurality, Plurality.vaBallot), (PluralityTop2, PluralityTop2.vaBallot),
                                  (IRV, IRV.vaBallot), (Approval, Approval.vaBallot),
                                  (ApprovalTop2, ApprovalTop2.vaBallot),
                                  (STAR, STAR.vaBallot), Minimax], 72, 12, 2000)
swva12.saveFile("swva12new", False)
swva12.chart()

# %%
approvalStrats = CID(KSModel(), [(Approval, Approval.zeroInfoBallot, {'pickiness':0}), (Approval, Approval.zeroInfoBallot, {'pickiness':0.4}),
                     (Approval, Approval.zeroInfoBallot, {'pickiness':0.8}), (Approval, Approval.vaBallot)],
                     72, 6, 10000)
approvalStrats.saveFile("approvalcid", False)
approvalStrats.chart()

# %%
approvalStrats.chart(False)

# %%
STARStrats = CID(KSModel(), [STAR, (STAR, STAR.zeroInfoBallot, {'exponent': 1.5, 'bottomSD': float('inf')}),
                             (STAR, STAR.zeroInfoBallot, {'exponent': 2, 'bottomSD': float('inf')}),
                             (STAR, STAR.zeroInfoBallot, {'exponent': 1, 'bottomSD': 0.5}),
                             (STAR, STAR.zeroInfoBallot, {'exponent': 1.4, 'bottomSD': 0.8}),
                             (STAR, STAR.vaBallot),
                             (STAR, STAR.vaBallot, {'scoreImportance': 0.5}),
                             (STAR, STAR.vaBallot, {'scoreImportance': 0.05})],
                             72, 6, 5000)
STARStrats.saveFile("starcid")
STARStrats.chart(False)

# %%
otherSWMethods = CID(KSModel(), [Score, Borda, SmithIRV, Schulze, Rp, RankedRobin, ITRV], 72, 6, 5000)
otherSWMethods.saveFile("othersw", False)
otherSWMethods.chart()

# %%
otherMWMethods = CID(KSModel(), [RRV, (BlockApproval, BlockApproval.zeroInfoBallot), BlockSTAR, PBV], 72, 10, 1000, 4)
otherMWMethods.saveFile("othermw", False)
otherMWMethods.chart()

# %%
randomElections = CID(RandomModel(),
                      [Plurality, PluralityTop2, IRV, (Approval, Approval.zeroInfoBallot), (ApprovalTop2, ApprovalTop2.zeroInfoBallot), STAR, Minimax],
                      72, 6, 5000)
randomElections.saveFile("randomCID", False)
randomElections.chart()

# %%
spatial2 = CID(DimModel(ndims=2, dimWeights=[1,1]),
               [Plurality, PluralityTop2, IRV, (Approval, Approval.zeroInfoBallot), (ApprovalTop2, ApprovalTop2.zeroInfoBallot), STAR, Minimax],
                72, 6, 5000)
spatial2.saveFile("spatial2CID", False)
spatial2.chart()

# %%
spatial3 = CID(DimModel(ndims=3, dimWeights=[1,1,1]),
               [Plurality, PluralityTop2, IRV, (Approval, Approval.zeroInfoBallot), (ApprovalTop2, ApprovalTop2.zeroInfoBallot), STAR, Minimax],
                72, 6, 5000)
spatial3.saveFile("spatial3CID", False)
spatial3.chart()

# %%
hugeb = CID(KSModel(), [Plurality, PluralityTop2, IRV, (Approval, Approval.zeroInfoBallot), (ApprovalTop2, ApprovalTop2.zeroInfoBallot), STAR, Minimax], 75, 6, 5000, numBuckets=25)

# %%
stratComparison = CID(KSModel(), [Plurality, (Plurality, Plurality.vaBallot), PluralityTop2, (PluralityTop2, PluralityTop2.vaBallot),
                                  IRV, (IRV, IRV.vaBallot),
                                  (Approval, Approval.zeroInfoBallot), (Approval, Approval.vaBallot),
                                  (ApprovalTop2, ApprovalTop2.zeroInfoBallot), (ApprovalTop2, ApprovalTop2.vaBallot),
                                  STAR, (STAR, STAR.vaBallot)], 72, 6, 2000)
stratComparison.chart(methodOnly=False)
