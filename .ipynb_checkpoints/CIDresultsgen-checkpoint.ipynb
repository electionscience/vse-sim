# %%
from cid import *

# %%
plur = CID(KSModel(), [Plurality], 35, 6, 5000)
plur.chart()

# %%
basesw = CID(KSModel(), [Plurality, PluralityTop2, IRV, (Approval, Approval.zeroInfoBallot), (ApprovalTop2, ApprovalTop2.zeroInfoBallot), STAR, Minimax],
             35, 6, 1000)
basesw.chart()

# %%
hugeb = CID(KSModel(), [Plurality, PluralityTop2, IRV, (Approval, Approval.zeroInfoBallot), (ApprovalTop2, ApprovalTop2.zeroInfoBallot), STAR, Minimax], 75, 6, 5000, numBuckets=25)

# %%
smallDevs = CID(KSModel(), [Plurality, PluralityTop2, IRV, (Approval, Approval.zeroInfoBallot), (ApprovalTop2, ApprovalTop2.zeroInfoBallot), STAR, Minimax],
             35, 6, 1000, utilChange = 0.02)

# %%
basemw = CID(KSModel(), [STV, AllocatedScore, SequentialMonroe], 75, 10, 5000, 4)
basemw.chart()

# %%
mwutils = CID(KSModel(), [STV, AllocatedScore, SequentialMonroe], 35, 10, 500, 4, sorter=utilDeviation)
mwutils.chart()

# %%
sw3 = CID(KSModel(), [Plurality, PluralityTop2, IRV, (Approval, Approval.zeroInfoBallot), (ApprovalTop2, ApprovalTop2.zeroInfoBallot), STAR, Minimax],
          35, 3, 5000)
sw3.chart()

# %%
sw12 = CID(KSModel(), [Plurality, PluralityTop2, IRV, (Approval, Approval.zeroInfoBallot), (ApprovalTop2, ApprovalTop2.zeroInfoBallot), STAR, Minimax],
           35, 12, 1000)
sw12.chart()

# %%
mw20 = CID(KSModel(), [STV, AllocatedScore, SequentialMonroe], 35, 20, 500, 4)
mw20.chart()

# %%
mw2winners = CID(KSModel(), [STV, AllocatedScore, SequentialMonroe], 35, 10, 1000, 2)
mw2winners.chart()

# %%
utilsw = CID(KSModel(), [Plurality, PluralityTop2, IRV, (Approval, Approval.zeroInfoBallot), (ApprovalTop2, ApprovalTop2.zeroInfoBallot), STAR, Minimax], 
             35, 6, 1000, sorter=utilDeviation)
utilsw.chart()

# %%
utilsw.summarize()
# Out:
# ({'Plurality:honBallot{}': [0.0005813953488372093,
#    0.022093023255813953,
#    0.1511627906976744,
#    0.6122093023255814,
#    0.21395348837209302],
#   'PluralityTop2:honBallot{}': [0.043000914913083256,
#    0.0626715462031107,
#    0.2108874656907594,
#    0.41216834400731933,
#    0.27127172918572734],
#   'IRV:honBallot{}': [0.05429864253393665,
#    0.08054298642533937,
#    0.25656108597285066,
#    0.36425339366515835,
#    0.24434389140271492],
#   'Approval:zeroInfoBallot{}': [0.05647691618108472,
#    0.2545943523083819,
#    0.42536978933213804,
#    0.15015688032272523,
#    0.1134020618556701],
#   'ApprovalTop2:zeroInfoBallot{}': [0.1072019867549669,
#    0.19329470198675497,
#    0.326158940397351,
#    0.23137417218543047,
#    0.14197019867549668],
#   'STAR:honBallot{}': [0.18499197431781703,
#    0.2231139646869984,
#    0.24719101123595505,
#    0.1958266452648475,
#    0.14887640449438203],
#   'Minimax:honBallot{}': [0.1583011583011583,
#    0.19835907335907335,
#    0.26206563706563707,
#    0.23552123552123552,
#    0.14575289575289574]},
#  {'Plurality:honBallot{}': [1, 38, 260, 1053, 368],
#   'PluralityTop2:honBallot{}': [94, 137, 461, 901, 593],
#   'IRV:honBallot{}': [120, 178, 567, 805, 540],
#   'Approval:zeroInfoBallot{}': [126, 568, 949, 335, 253],
#   'ApprovalTop2:zeroInfoBallot{}': [259, 467, 788, 559, 343],
#   'STAR:honBallot{}': [461, 556, 616, 488, 371],
#   'Minimax:honBallot{}': [328, 411, 543, 488, 302]},
#  {'Plurality:honBallot{}': [1, 35, 225, 638, 116],
#   'PluralityTop2:honBallot{}': [57, 95, 314, 523, 258],
#   'IRV:honBallot{}': [73, 124, 351, 469, 232],
#   'Approval:zeroInfoBallot{}': [98, 363, 500, 116, 128],
#   'ApprovalTop2:zeroInfoBallot{}': [155, 287, 433, 263, 146],
#   'STAR:honBallot{}': [259, 305, 323, 217, 178],
#   'Minimax:honBallot{}': [188, 243, 326, 247, 109]},
#  {'Plurality:honBallot{}': [0, 3, 35, 415, 252],
#   'PluralityTop2:honBallot{}': [37, 42, 147, 378, 335],
#   'IRV:honBallot{}': [47, 54, 216, 336, 308],
#   'Approval:zeroInfoBallot{}': [28, 205, 449, 219, 125],
#   'ApprovalTop2:zeroInfoBallot{}': [104, 180, 355, 296, 197],
#   'STAR:honBallot{}': [202, 251, 293, 271, 193],
#   'Minimax:honBallot{}': [140, 168, 217, 241, 193]})

# %%
manyBuckets = CID(KSModel(), 
                  [Plurality, PluralityTop2, IRV, (Approval, Approval.zeroInfoBallot), (ApprovalTop2, ApprovalTop2.zeroInfoBallot), STAR, Minimax],
                  100, 6, 10000, numBuckets=20)

# %%
smallChange = CID(KSModel(), [Plurality, PluralityTop2, IRV, (Approval, Approval.zeroInfoBallot), (ApprovalTop2, ApprovalTop2.zeroInfoBallot), STAR, Minimax],
                  35, 6, 10000, utilShift= 0.02)
basesw.chart()

# %%
stratComparison = CID(KSModel(), [Plurality, (Plurality, Plurality.vaBallot), PluralityTop2, (PluralityTop2, PluralityTop2.vaBallot), IRV,
                                  (Approval, Approval.zeroInfoBallot, {'pickiness':0}), (Approval, Approval.zeroInfoBallot{'pickiness':0.4}),
                                  (Approval, Approval.zeroInfoBallot{'pickiness':0.8}), STAR, (STAR, STAR.vaBallot), Minimax], 35, 6, 2000)
stratComparison.chart(methodOnly=False)

# %%
otherSWMethods = CID(KSModel(), [Score, Borda, SmithIRV, Schultz, Rp, RankedRobin, Raynaud, ITRV], 35, 6, 2000)

# %%
otherMWMethods = CID(KSModel(), [SNTV, RRV, (BlockApproval, BlockApproval.vaBallot), BlockSTAR, PBV], 35, 10, 1000, 4)

# %%
randomElections = CID(RandomModel(),
                      [Plurality, PluralityTop2, IRV, (Approval, Approval.zeroInfoBallot), (ApprovalTop2, ApprovalTop2.zeroInfoBallot), STAR, Minimax],
                      75, 6, 2000, numBuckets=25)
randomElections.chart()

# %%
spatial2 = CID(DimModel(ndims=2, dimWeights=[1,1]),
               [Plurality, PluralityTop2, IRV, (Approval, Approval.zeroInfoBallot), (ApprovalTop2, ApprovalTop2.zeroInfoBallot), STAR, Minimax],
                35, 6, 5000)

# %%
spatial3 = CID(DimModel(ndims=3, dimWeights=[1,1,1]),
               [Plurality, PluralityTop2, IRV, (Approval, Approval.zeroInfoBallot), (ApprovalTop2, ApprovalTop2.zeroInfoBallot), STAR, Minimax],
                35, 6, 5000)
